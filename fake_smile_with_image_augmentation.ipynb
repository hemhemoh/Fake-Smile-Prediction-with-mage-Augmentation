# %% [markdown]
# <a href="https://colab.research.google.com/github/hemhemoh/Fake-Smile-Prediction-with-mage-Augmentation/blob/main/fake_smile_with_image_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Fake Smile Detection

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
import os
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time

# %%
for dirname, _, filenames in os.walk('/content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/README.dataset.txt
# /content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/README.roboflow.txt
# /content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/train/labels.cache
# /content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/train/images/fake12_jpg.rf.68d80a24317ac9ed341cd0a620ad1147.jpg
# /content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/train/images/fake10_jpg.rf.d3bf10aa2426816ae5beda6eeac9f937.jpg
# /content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/train/images/fake12_jpg.rf.14e9f663fcfc71e48d036c0568e5f3d0.jpg
# /content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/train/images/fake14_jpg.rf.3c04d7cd310ddeac7071b47a6d9e1fd5.jpg
# /content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/train/images/fake11_jpg.rf.db4a78e8fab6bdd249c2e0dfeff28108.jpg
# ...

# %%
os.chdir('/content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch')

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch'

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
!#git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images
# Out:
# /content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/yolov5
#      |████████████████████████████████| 636 kB 5.3 MB/s

# %%
# Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2, ..]
path: os.path.join("/content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch")
train: os.path.join("/content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch", '/content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/train')  # train images (relative to 'path') 
val: os.path.join("/content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch", '/content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/valid')  # val images (relative to 'path') 
#test:  os.path.join("/content/drive/MyDrive/Fake Smile Prediction.v1-final-fake-smile-predction-data.yolov5Pytorch", '/content/drive/MyDrive/Fake Smile Prediction.v1-final-fake-smile-predction-data.yolov5Pytorch/test')# test images (optional)

# Classes
nc: 3  # number of classes
names: ['Fake', 'Real', 'Neutral']  # class names

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/yolov5'

# %%
'/content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch'
# Out:
# '/content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch'

# %%
# !python detect.py --weights yolov5s.pt --img 23 --conf 0.25 --source "/content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/train/images/fake10_jpg.rf.b7214a4020fcba88d2405c1c125c9984.jpg"
# Out:
# ...
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/train/images/fake10_jpg.rf.b7214a4020fcba88d2405c1c125c9984.jpg, imgsz=[23, 23], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 2021-9-30 torch 1.9.0+cu111 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients
# WARNING: --img-size [23, 23] must be multiple of max stride 32, updating to [32, 32]
# image 1/1 /content/drive/MyDrive/Fake Smile Prediction.v2-fake-smile.yolov5pytorch/train/images/fake10_jpg.rf.b7214a4020fcba88d2405c1c125c9984.jpg: 32x32 1 person, Done. (0.022s)
# ...

# %%
# !python train.py --img 640  --batch 64 --epochs 500 --data data.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=500, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, entity=None, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=100
# remote: Enumerating objects: 578, done.
# remote: Counting objects: 100% (279/279), done.
# remote: Compressing objects: 100% (19/19), done.
# github: Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# remote: Total 578 (delta 269), reused 264 (delta 260), pack-reused 299
# Receiving objects: 100% (578/578), 156.63 KiB | 478.00 KiB/s, done.
# ...
